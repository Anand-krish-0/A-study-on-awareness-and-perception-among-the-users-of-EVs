# %%
import pandas as pd

# %%
df=pd.read_csv('d:\pg project responses/analyze using python/fre_table_responce1.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ANAND\AppData\Local\Temp\ipykernel_14168\2141672652.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df=pd.read_csv('d:\pg project responses/analyze using python/fre_table_responce1.csv')
#    ratings  aq1  aq2  aq3  aq4  bq1  bq2  bq3  bq4  bq5  ...  dq5  eq1  eq2  \
# 0        1    1    2    5    6    1    7    2    2    9  ...   58    5    5
# 1        2   12    3   17    9   13    8   17   13   23  ...   46   25   16
# 2        3   45   88   94   51   71   29   64   66   51  ...   66   57   62
# 3        4  129   90   76  108   99  103  100  106   84  ...   22   92   97
# 4        5   14   18    9   27   17   54   18   14   34  ...    9   22   21
#
#    eq3  eq4  eq5  fq1  fq2  fq3  fq4
# 0    7    3   54    5    5    3    1
# 1   23   15   13    9    8    7    7
# 2   88  105   60   45   46   35   50
# 3   70   63   50   66   76   69   65
# ...

# %%
df.columns
# Out:
# Index(['ratings', 'aq1', 'aq2', 'aq3', 'aq4', 'bq1', 'bq2', 'bq3', 'bq4',
#        'bq5', 'cq1', 'cq2', 'cq3', 'cq4', 'dq1', 'dq2', 'dq3', 'dq4', 'dq5',
#        'eq1', 'eq2', 'eq3', 'eq4', 'eq5', 'fq1', 'fq2', 'fq3', 'fq4'],
#       dtype='object')

# %%
def numerical_univariate_analysis(df):
    for col_name in df:
        print("*"*10, col_name, "*"*10)
        print(df[col_name].agg(['min', 'max', 'mean', 'median', 'std']))
        print()

# %%
numerical_univariate_analysis(df)
# Out:
# ********** ratings **********
# min       1.000000
# max       5.000000
# mean      3.000000
# median    3.000000
# std       1.581139
# Name: ratings, dtype: float64
#
# ********** aq1 **********
# min         1.000000
# max       129.000000
# mean       40.200000
# median     14.000000
# std        52.265668
# Name: aq1, dtype: float64
#
# ********** aq2 **********
# min        2.000000
# max       90.000000
# mean      40.200000
# median    18.000000
# std       45.002222
# Name: aq2, dtype: float64
#
# ********** aq3 **********
# min        5.0000
# max       94.0000
# mean      40.2000
# median    17.0000
# std       41.6137
# Name: aq3, dtype: float64
#
# ********** aq4 **********
# min         6.000000
# max       108.000000
# mean       40.200000
# median     27.000000
# std        41.924933
# Name: aq4, dtype: float64
#
# ********** bq1 **********
# min        1.000000
# max       99.000000
# mean      40.200000
# median    17.000000
# std       42.487645
# ...

# %%
def discrete_univariate_analysis(discrete_data):
    for col_name in discrete_data:
        print("*"*10, col_name, "*"*10)
        print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
        print('Value Counts: \n', discrete_data[col_name].value_counts())
        print()

# %%
discrete_univariate_analysis(df)
# Out:
# ********** ratings **********
# count                    5
# nunique                  5
# unique     [1, 2, 3, 4, 5]
# Name: ratings, dtype: object
# Value Counts:
#  ratings
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64
#
# ********** aq1 **********
# count                         5
# nunique                       5
# unique     [1, 12, 45, 129, 14]
# Name: aq1, dtype: object
# Value Counts:
#  aq1
# 1      1
# 12     1
# 45     1
# 129    1
# 14     1
# Name: count, dtype: int64
#
# ********** aq2 **********
# count                       5
# nunique                     5
# unique     [2, 3, 88, 90, 18]
# Name: aq2, dtype: object
# Value Counts:
#  aq2
# 2     1
# 3     1
# 88    1
# 90    1
# 18    1
# Name: count, dtype: int64
#
# ********** aq3 **********
# count                       5
# nunique                     5
# unique     [5, 17, 94, 76, 9]
# Name: aq3, dtype: object
# Value Counts:
#  aq3
# 5     1
# 17    1
# 94    1
# 76    1
# 9     1
# ...

# %%
data=pd.read_csv('d:\pg project responses/responces.csv')
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ANAND\AppData\Local\Temp\ipykernel_14168\1287987192.py:1: SyntaxWarning: invalid escape sequence '\p'
#   data=pd.read_csv('d:\pg project responses/responces.csv')
#                 Name  Gender      Age Employment Status  \
# 0    Anish Glorisha   Female  18 - 27           Student
# 1               Hari    Male  18 - 27           Student
# 2    CHINNAPPANDI J     Male  18 - 27           Student
# 3      P. Manikandan    Male  18 - 27           Student
# 4          Divyasri   Female  18 - 27           Student
# ..               ...     ...      ...               ...
# 196      Karuppaiya     Male  28 - 43          Employed
# 197           Vishal    Male  18 - 27          Employed
# 198          Nivedha  Female  18 - 27          Employed
# 199          Xavier     Male  18 - 27          Employed
# 200   S.Gangaiarasan    Male  44 - 59          Employed
#
# ...

# %%
dd=pd.crosstab(data['Gender'],data['Age'])
dd.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
pd.crosstab(
    index=[data['Gender']],
    columns=[data['Employment Status'],data['Area of Residence']]
)
# Out:
# Employment Status Employed       Self Employed       Student       Unemployed  \
# Area of Residence    Rural Urban         Rural Urban   Rural Urban      Rural
# Gender
# Female                   0    13             1     2      13    17          2
# Male                    20    51             4     6      29    29          5
#
# Employment Status
# Area of Residence Urban
# Gender
# Female                7
# Male                  2

# %%
pd.crosstab(
    index=[data['Gender'], df['Age']],
    columns=[data['Employment Status'],data['Education Qualification']],
    values=data['Name']
    aggfunc='value_counts'
)
# Out:
#   Cell In[73], line 4
#     values=data['Name']
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
data1=data.rename(columns={'1.1 Are electric vehicles better performing compared to fuel vehicles?':'1.1 current awareness level'},inplace=True)
data1=data.rename(columns={'1.2  Are electric vehicles easy to drive then fuel vehicles?':'1.2 current awareness level'},inplace=True)
data1=data.rename(columns={'1.3 What is your opinion about blasting(firing) issues of electric vehicles?':'1.3 current awareness level'},inplace=True)
data1=data.rename(columns={'1.4 Do you agree that the EV’s are best alternative vehicles to fuel vehicles for reducing the fuel cost?':'1.4 current awareness level'},inplace=True)
data1=data.rename(columns={'2.1  How does the performance of electric vehicles compared to fuel vehicles in your view?':'2.1 user satisfaction'},inplace=True)
data1=data.rename(columns={'2.2 Do you agree that the EV’s are noiseless and offer smoother acceleration and declaration, avoid of the vibration, gear shifting and sounds of the internal consumption engine?':'2.2 user satisfaction'},inplace=True)
data1=data.rename(columns={'2.3  How would you rate the driving experience of EV’s compared to traditional fuel vehicles?':'2.3 user satisfaction'},inplace=True)
data1=data.rename(columns={'2.4  Are you satisfied with the overall cost of owning and maintaining EV’s compared to a fuel vehicles?':'2.4 user satisfaction'},inplace=True)
data1=data.rename(columns={'2.5 Will electric vehicles refill the place of traditional fuel vehicles?':'2.5 user satisfaction'},inplace=True)
data1=data.rename(columns={'3.1 Is the charging type is better to fuel type in your site?':'3.1 charging infrastructure facilities'},inplace=True)
data1=data.rename(columns={'3.2  What is your opinion on the availability and accessibility of charging stations for electric vehicles?':'3.2 charging infrastructure facilities'},inplace=True)
data1=data.rename(columns={'3.3  Are the enough charging points in your area?':'3.3 charging infrastructure facilities'},inplace=True)
data1=data.rename(columns={'3.4  What is your opinion on home charging?':'3.4 charging infrastructure facilities'},inplace=True)
data1=data.rename(columns={'4.1  How do you precieve the initial cost of EV’s compared to traditional vehicles?':'4.1 cost consideration'},inplace=True)
data1=data.rename(columns={'4.2 How much cheaper is electricity generally than petrol or diesel per mile?':'4.2 cost consideration'},inplace=True)
data1=data.rename(columns={'4.3  How is the maintenance cost of EV’s compared to fuel vehicles?':'4.3 cost consideration'},inplace=True)
data1=data.rename(columns={'4.4  What is your opinion on cost of buying spare parts of electric vehicles in Tamil Nadu?':'4.4 cost consideration'},inplace=True)
data1=data.rename(columns={"4.5   How is the resale value of an EV's compared to a traditional fuel vehicles?":'4.5 cost consideration'},inplace=True)
data1=data.rename(columns={'5.1  How familiar are you with EV’s and their features?':'5.1 consumer preference'},inplace=True)
data1=data.rename(columns={'5.2  Are you attracted to EV’s because of the technological advancement?':'5.2 consumer preference'},inplace=True)
data1=data.rename(columns={'5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles?':'5.3 consumer preference'},inplace=True)
data1=data.rename(columns={'5.4  If you were to buy a vehicle, would you consider EV’s?':'5.4 consumer preference'},inplace=True)
data1=data.rename(columns={'5.5 What do you think of the government encouraging e-vehicle sales?':'5.5 consumer preference'},inplace=True)
data1=data.rename(columns={'6.1  Are electric vehicles polluting like other traditional fuel vehicles?':'6.1 environmental considerations'},inplace=True)
data1=data.rename(columns={'6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment?':'6.2 environmental considerations'},inplace=True)
data1=data.rename(columns={'6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces?':'6.3 environmental considerations'},inplace=True)
data1=data.rename(columns={'6.4  Are the applications of EV’s support to eco- friendly transportation?':'6.4 environmental considerations'},inplace=True)

# %%
data.head()
# Out:
#               Name  Gender      Age Employment Status  \
# 0  Anish Glorisha   Female  18 - 27           Student
# 1             Hari    Male  18 - 27           Student
# 2  CHINNAPPANDI J     Male  18 - 27           Student
# 3    P. Manikandan    Male  18 - 27           Student
# 4        Divyasri   Female  18 - 27           Student
#
#   Education Qualification       District Area of Residence  \
# 0            Post Graduate   Coimbatore              Urban
# 1            Post Graduate    coimbatore             Rural
# 2            Post Graduate    coimbatore             Rural
# 3            Post Graduate  Viruthunagar             Urban
# 4            Post Graduate   Dharmapuri              Urban
#
#   which type of Vehicle do you have? Do you have an Electric Vehicle?  \
# 0                             Petrol                               No
# 1                             Diesel                              Yes
# ...

# %%
data.to_csv('D:\pg project responses/analyze using python/respond_col_nam_changed.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ANAND\AppData\Local\Temp\ipykernel_14168\702229151.py:1: SyntaxWarning: invalid escape sequence '\p'
#   data.to_csv('D:\pg project responses/analyze using python/respond_col_nam_changed.csv')

# %%
d_spli=data.iloc[ : ,3:6]
d_spli.value_counts()
# Out:
# Employment Status  Education Qualification   District
# Student            Post Graduate             Coimbatore      13
# Employed           Under Graduate            Coimbatore       6
# Student            Under Graduate            Coimbatore       6
# Employed           Under Graduate            Vellore          6
# Student            Post Graduate             Pudukkottai      6
#                                                              ..
# Unemployed         Under Graduate            Selam            1
#                                              Thanjavur        1
#                                              Theni            1
#                                              Thothukudi       1
#                                              Tiruvarur        1
# Name: count, Length: 130, dtype: int64

# %%
data.dtypes
# Out:
# Name                                      object
# Gender                                    object
# Age                                       object
# Employment Status                         object
# Education Qualification                   object
# District                                  object
# Area of Residence                         object
# which type of Vehicle do you have?        object
# Do you have an Electric Vehicle?          object
# 1.1 current awareness level               object
# 1.2 current awareness level               object
# 1.3 current awareness level               object
# 1.4 current awareness level               object
# 2.1 user satisfaction                     object
# 2.2 user satisfaction                     object
# 2.3 user satisfaction                     object
# 2.4 user satisfaction                     object
# 2.5 user satisfaction                     object
# 3.1 charging infrastructure facilities    object
# ...

# %%
discrete_univariate_analysis(data.iloc[ : ,3:10])
# Out:
# ********** Employment Status **********
# count                                                 201
# nunique                                                 4
# unique     [Student, Unemployed, Employed, Self Employed]
# Name: Employment Status, dtype: object
# Value Counts:
#  Employment Status
# Student          88
# Employed         84
# Unemployed       16
# Self Employed    13
# Name: count, dtype: int64
#
# ********** Education Qualification  **********
# count                                                    201
# nunique                                                    6
# unique     [Post Graduate, School, Under Graduate, Doctor...
# Name: Education Qualification , dtype: object
# Value Counts:
#  Education Qualification
# Under Graduate    102
# Post Graduate      71
# School             13
# Diploma            11
# Doctorate           2
# ITI                 2
# Name: count, dtype: int64
#
# ********** District **********
# ...

# %%
discrete_univariate_analysis(data.iloc[ : ,10:16])
# Out:
# ********** 1.2 current awareness level **********
# count                                              201
# nunique                                              5
# unique     [neutral, very easy, very hard, easy, hard]
# Name: 1.2 current awareness level, dtype: object
# Value Counts:
#  1.2 current awareness level
# easy         90
# neutral      88
# very easy    18
# hard          3
# very hard     2
# Name: count, dtype: int64
#
# ********** 1.3 current awareness level **********
# count                                            201
# nunique                                            5
# unique     [Often, Always, Sometimes, Rarely, Never]
# Name: 1.3 current awareness level, dtype: object
# Value Counts:
#  1.3 current awareness level
# Sometimes    94
# Rarely       76
# Often        17
# Never         9
# Always        5
# Name: count, dtype: int64
#
# ********** 1.4 current awareness level **********
# count                                                    201
# ...

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
