# %%
import pandas as pd

# %%
df=pd.read_csv('d:\pg project responses\cust_res.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ANAND\AppData\Local\Temp\ipykernel_648\852158826.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df=pd.read_csv('d:\pg project responses\cust_res.csv')
#      Unnamed: 0             Name  Gender      Age Employment Status  \
# 0             0  Anish Glorisha   Female  18 - 27           Student
# 1             1             Hari    Male  18 - 27           Student
# 2             2  CHINNAPPANDI J     Male  18 - 27           Student
# 3             3    P. Manikandan    Male  18 - 27           Student
# 4             4        Divyasri   Female  18 - 27           Student
# ..          ...              ...     ...      ...               ...
# 196         196      Karuppaiya     Male  28 - 43          Employed
# 197         197           Vishal    Male  18 - 27          Employed
# 198         198          Nivedha  Female  18 - 27          Employed
# ...

# %%
pip install scikitlearn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement scikitlearn (from versions: none)
# ERROR: No matching distribution found for scikitlearn

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "packages"
