# %%
import pandas as pd

# %%
data=pd.read_csv('d:\pg project responses/responces.csv')
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ANAND\AppData\Local\Temp\ipykernel_5428\3592971805.py:1: SyntaxWarning: invalid escape sequence '\p'
#   data=pd.read_csv('d:\pg project responses/responces.csv')
#               Name  Gender      Age Employment Status  \
# 0  Anish Glorisha   Female  18 - 27           Student
# 1             Hari    Male  18 - 27           Student
# 2  CHINNAPPANDI J     Male  18 - 27           Student
# 3    P. Manikandan    Male  18 - 27           Student
# 4        Divyasri   Female  18 - 27           Student
#
#   Education Qualification       District Area of Residence  \
# 0            Post Graduate   Coimbatore              Urban
# 1            Post Graduate    coimbatore             Rural
# 2            Post Graduate    coimbatore             Rural
# 3            Post Graduate  Viruthunagar             Urban
# 4            Post Graduate   Dharmapuri              Urban
#
#   which type of Vehicle do you have? Do you have an Electric Vehicle?  \
# 0                             Petrol                               No
# 1                             Diesel                              Yes
# 2                             Petrol                              Yes
# 3                             Diesel                              Yes
# 4                             Petrol                               No
#
#   1.1 Are electric vehicles better performing compared to fuel vehicles?  ...  \
# 0                                               fair                      ...
# 1                                               good                      ...
# 2                                               poor                      ...
# 3                                          very poor                      ...
# 4                                               good                      ...
#
#   4.5   How is the resale value of an EV's compared to a traditional fuel vehicles?  \
# 0                                               High
# 1                                                Low
# 2                                           Very low
# 3                                            Neutral
# 4                                               High
#
#   5.1  How familiar are you with EV’s and their features?  \
# 0                                           familiar
# 1                                    Very unfamiliar
# 2                                           familiar
# 3                                  Somewhat familiar
# 4                                           familiar
#
#   5.2  Are you attracted to EV’s because of the technological advancement?  \
# 0                                          Attracted
# 1                               Highly not attracted
# 2                                      Not attracted
# 3                               Highly not attracted
# 4                                      Not attracted
#
#   5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles?  \
# 0                                     Very satisfied
# 1                               moderately satisfied
# 2                                     Very satisfied
# 3                               moderately satisfied
# 4                                 Slightly satisfied
#
#   5.4  If you were to buy a vehicle, would you consider EV’s?  \
# 0                                Somewhat considered
# 1                                Somewhat considered
# 2                                Somewhat considered
# 3                                     Not considered
# 4                                Somewhat considered
#
#   5.5 What do you think of the government encouraging e-vehicle sales?  \
# 0                                               Good
# 1                                            Average
# 2                                               Fair
# 3                                               Fair
# 4                                               Fair
#
#   6.1  Are electric vehicles polluting like other traditional fuel vehicles?  \
# 0                                  Similar to others
# 1                                   Highly polluting
# 2                                      Not polluting
# 3                                  Similar to others
# 4                                 slightly polluting
#
#   6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment?  \
# 0                                            Neutral
# 1                                            Useless
# 2                                            Usefull
# 3                                            Usefull
# 4                                            Neutral
#
#   6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces?  \
# 0                                             Reduce
# 1                                      Didn't reduce
# 2                                  Definitely reduce
# 3                                             Reduce
# 4                                             Reduce
#
#   6.4  Are the applications of EV’s support to eco- friendly transportation?
# 0                                            neutral
# 1                                            support
# 2                                 definitely support
# 3                                            neutral
# 4                                            neutral
#
# [5 rows x 36 columns]

# %%
data.columns
# Out:
# Index(['Name', 'Gender', 'Age', 'Employment Status',
#        'Education Qualification ', 'District', 'Area of Residence',
#        'which type of Vehicle do you have?',
#        'Do you have an Electric Vehicle?',
#        '1.1 Are electric vehicles better performing compared to fuel vehicles?',
#        '1.2  Are electric vehicles easy to drive then fuel vehicles?',
#        '1.3 What is your opinion about blasting(firing) issues of electric vehicles?',
#        '1.4 Do you agree that the EV’s are best alternative vehicles to fuel vehicles for reducing the fuel cost?',
#        '2.1  How does the performance of electric vehicles compared to fuel vehicles in your view?',
#        '2.2 Do you agree that the EV’s are noiseless and offer smoother acceleration and declaration, avoid of the vibration, gear shifting and sounds of the internal consumption engine?',
#        '2.3  How would you rate the driving experience of EV’s compared to traditional fuel vehicles?',
#        '2.4  Are you satisfied with the overall cost of owning and maintaining EV’s compared to a fuel vehicles?',
#        '2.5 Will electric vehicles refill the place of traditional fuel vehicles?',
#        '3.1 Is the charging type is better to fuel type in your site?',
#        '3.2  What is your opinion on the availability and accessibility of charging stations for electric vehicles?',
#        '3.3  Are the enough charging points in your area?',
#        '3.4  What is your opinion on home charging?',
#        '4.1  How do you precieve the initial cost of EV’s compared to traditional vehicles?',
#        '4.2 How much cheaper is electricity generally than petrol or diesel per mile?',
#        '4.3  How is the maintenance cost of EV’s compared to fuel vehicles?',
#        '4.4  What is your opinion on cost of buying spare parts of electric vehicles in Tamil Nadu?',
#        '4.5   How is the resale value of an EV's compared to a traditional fuel vehicles?',
#        '5.1  How familiar are you with EV’s and their features?',
#        '5.2  Are you attracted to EV’s because of the technological advancement?',
#        '5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles?',
#        '5.4  If you were to buy a vehicle, would you consider EV’s?',
#        '5.5 What do you think of the government encouraging e-vehicle sales?',
#        '6.1  Are electric vehicles polluting like other traditional fuel vehicles?',
#        '6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment?',
#        '6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces?',
#        '6.4  Are the applications of EV’s support to eco- friendly transportation?'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Name', 'Gender', 'Age', 'Employment Status',
#        'Education Qualification ', 'District', 'Area of Residence',
#        'which type of Vehicle do you have?',
#        'Do you have an Electric Vehicle?',
#        '1.1 Are electric vehicles better performing compared to fuel vehicles?',
#        '1.2  Are electric vehicles easy to drive then fuel vehicles?',
#        '1.3 What is your opinion about blasting(firing) issues of electric vehicles?',
#        '1.4 Do you agree that the EV’s are best alternative vehicles to fuel vehicles for reducing the fuel cost?',
#        '2.1  How does the performance of electric vehicles compared to fuel vehicles in your view?',
#        '2.2 Do you agree that the EV’s are noiseless and offer smoother acceleration and declaration, avoid of the vibration, gear shifting and sounds of the internal consumption engine?',
#        '2.3  How would you rate the driving experience of EV’s compared to traditional fuel vehicles?',
#        '2.4  Are you satisfied with the overall cost of owning and maintaining EV’s compared to a fuel vehicles?',
#        '2.5 Will electric vehicles refill the place of traditional fuel vehicles?',
#        '3.1 Is the charging type is better to fuel type in your site?',
#        '3.2  What is your opinion on the availability and accessibility of charging stations for electric vehicles?',
#        '3.3  Are the enough charging points in your area?',
#        '3.4  What is your opinion on home charging?',
#        '4.1  How do you precieve the initial cost of EV’s compared to traditional vehicles?',
#        '4.2 How much cheaper is electricity generally than petrol or diesel per mile?',
#        '4.3  How is the maintenance cost of EV’s compared to fuel vehicles?',
#        '4.4  What is your opinion on cost of buying spare parts of electric vehicles in Tamil Nadu?',
#        '4.5   How is the resale value of an EV's compared to a traditional fuel vehicles?',
#        '5.1  How familiar are you with EV’s and their features?',
#        '5.2  Are you attracted to EV’s because of the technological advancement?',
#        '5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles?',
#        '5.4  If you were to buy a vehicle, would you consider EV’s?',
#        '5.5 What do you think of the government encouraging e-vehicle sales?',
#        '6.1  Are electric vehicles polluting like other traditional fuel vehicles?',
#        '6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment?',
#        '6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces?',
#        '6.4  Are the applications of EV’s support to eco- friendly transportation?'],
#       dtype='object')

# %%
data.iloc[ : ,1:9].describe()
# Out:
#        Gender      Age Employment Status Education Qualification   \
# count     201      201               201                      201
# unique      2        3                 4                        6
# top      Male  18 - 27           Student           Under Graduate
# freq      146      143                88                      102
#
#            District Area of Residence which type of Vehicle do you have?  \
# count           201               201                                201
# unique           54                 2                                  4
# top     Coimbatore              Urban                             Petrol
# freq             30               127                                167
#
#        Do you have an Electric Vehicle?
# count                               201
# unique                                2
# top                                  No
# freq                                166

# %%
data.iloc[ : ,9:13].describe()
# Out:
#        1.1 Are electric vehicles better performing compared to fuel vehicles?  \
# count                                                 201
# unique                                                  5
# top                                                  good
# freq                                                  129
#
#        1.2  Are electric vehicles easy to drive then fuel vehicles?  \
# count                                                 201
# unique                                                  5
# top                                                  easy
# freq                                                   90
#
#        1.3 What is your opinion about blasting(firing) issues of electric vehicles?  \
# count                                                 201
# unique                                                  5
# top                                             Sometimes
# freq                                                   94
#
#        1.4 Do you agree that the EV’s are best alternative vehicles to fuel vehicles for reducing the fuel cost?
# count                                                 201
# unique                                                  5
# top                                                 Agree
# freq                                                  108

# %%
data.iloc[ : ,13:18].describe()
# Out:
#        2.1  How does the performance of electric vehicles compared to fuel vehicles in your view?  \
# count                                                 201
# unique                                                  5
# top                                                  Good
# freq                                                   99
#
#        2.2 Do you agree that the EV’s are noiseless and offer smoother acceleration and declaration, avoid of the vibration, gear shifting and sounds of the internal consumption engine?  \
# count                                                 201
# unique                                                  5
# top                                                 Agree
# freq                                                  103
#
#        2.3  How would you rate the driving experience of EV’s compared to traditional fuel vehicles?  \
# count                                                 201
# unique                                                  5
# top                                                  Good
# freq                                                  100
#
#        2.4  Are you satisfied with the overall cost of owning and maintaining EV’s compared to a fuel vehicles?  \
# count                                                 201
# unique                                                  5
# top                                             Satisfied
# freq                                                  106
#
#        2.5 Will electric vehicles refill the place of traditional fuel vehicles?
# count                                                 201
# unique                                                  5
# top                                                Refill
# freq                                                   84

# %%
data.iloc[ : ,18:22].describe()
# Out:
#        3.1 Is the charging type is better to fuel type in your site?  \
# count                                                 201
# unique                                                  5
# top                                                  Good
# freq                                                   80
#
#        3.2  What is your opinion on the availability and accessibility of charging stations for electric vehicles?  \
# count                                                 201
# unique                                                  5
# top                                                  Poor
# freq                                                   71
#
#        3.3  Are the enough charging points in your area?  \
# count                                                201
# unique                                                 5
# top                                              Nothing
# freq                                                  83
#
#        3.4  What is your opinion on home charging?
# count                                          201
# unique                                           5
# top                                           Good
# freq                                            99

# %%
data.iloc[ : ,22:27].describe()
# Out:
#        4.1  How do you precieve the initial cost of EV’s compared to traditional vehicles?  \
# count                                                 201
# unique                                                  5
# top                                         both are same
# freq                                                   76
#
#        4.2 How much cheaper is electricity generally than petrol or diesel per mile?  \
# count                                                 201
# unique                                                  5
# top                                                 Cheap
# freq                                                   99
#
#        4.3  How is the maintenance cost of EV’s compared to fuel vehicles?  \
# count                                                 201
# unique                                                  5
# top                                         Both are same
# freq                                                   98
#
#        4.4  What is your opinion on cost of buying spare parts of electric vehicles in Tamil Nadu?  \
# count                                                 201
# unique                                                  5
# top                                     similar to others
# freq                                                   94
#
#        4.5   How is the resale value of an EV's compared to a traditional fuel vehicles?
# count                                                 201
# unique                                                  5
# top                                               Neutral
# freq                                                   66

# %%
data.iloc[ : ,27:32].describe()
# Out:
#        5.1  How familiar are you with EV’s and their features?  \
# count                                                 201
# unique                                                  5
# top                                              familiar
# freq                                                   92
#
#        5.2  Are you attracted to EV’s because of the technological advancement?  \
# count                                                 201
# unique                                                  5
# top                                             Attracted
# freq                                                   97
#
#        5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles?  \
# count                                                 201
# unique                                                  5
# top                                  moderately satisfied
# freq                                                   88
#
#        5.4  If you were to buy a vehicle, would you consider EV’s?  \
# count                                                 201
# unique                                                  5
# top                                   Somewhat considered
# freq                                                  105
#
#        5.5 What do you think of the government encouraging e-vehicle sales?
# count                                                 201
# unique                                                  5
# top                                               Average
# freq                                                   60

# %%
data.iloc[ : ,32:36].describe()
# Out:
#        6.1  Are electric vehicles polluting like other traditional fuel vehicles?  \
# count                                                 201
# unique                                                  5
# top                                  Highly not polluting
# freq                                                   76
#
#        6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment?  \
# count                                                 201
# unique                                                  5
# top                                               Usefull
# freq                                                   76
#
#        6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces?  \
# count                                                 201
# unique                                                  5
# top                                     Definitely reduce
# freq                                                   87
#
#        6.4  Are the applications of EV’s support to eco- friendly transportation?
# count                                                 201
# unique                                                  5
# top                                    definitely support
# freq                                                   78

# %%
def discrete_univariate_analysis(discret_data):
    for col_name in discret_data:
        print("*"*10, col_name ,"*"*10)
        print(discret_data[col_name].agg(['count', 'nunique', 'unique']))
        print("value_counts: \n", discret_data[col_name].value_counts())
        print()

# %%
discrete_univariate_analysis(data.iloc[ : ,1:9])
# Out:
# ********** Gender **********
# count                 201
# nunique                 2
# unique     [Female, Male]
# Name: Gender, dtype: object
# value_counts:
#  Gender
# Male      146
# Female     55
# Name: count, dtype: int64
#
# ********** Age **********
# count                              201
# nunique                              3
# unique     [18 - 27, 28 - 43, 44 - 59]
# Name: Age, dtype: object
# value_counts:
#  Age
# 18 - 27    143
# 28 - 43     50
# 44 - 59      8
# Name: count, dtype: int64
#
# ********** Employment Status **********
# count                                                 201
# nunique                                                 4
# unique     [Student, Unemployed, Employed, Self Employed]
# Name: Employment Status, dtype: object
# value_counts:
#  Employment Status
# Student          88
# Employed         84
# Unemployed       16
# Self Employed    13
# Name: count, dtype: int64
#
# ********** Education Qualification  **********
# count                                                    201
# nunique                                                    6
# unique     [Post Graduate, School, Under Graduate, Doctor...
# Name: Education Qualification , dtype: object
# value_counts:
#  Education Qualification
# Under Graduate    102
# Post Graduate      71
# School             13
# Diploma            11
# Doctorate           2
# ITI                 2
# Name: count, dtype: int64
#
# ********** District **********
# count                                                    201
# nunique                                                   54
# unique     [Coimbatore , coimbatore, Viruthunagar, Dharma...
# Name: District, dtype: object
# value_counts:
#  District
# Coimbatore        30
# Pudukkottai       15
# Tiruppur           9
# Coimbatore         8
# Erode              8
# Krishnagiri        8
# Selam              7
# Vellore            7
# Ariyalur           6
# Trichy             6
# Vellore            6
# Tiruvarur          6
# Thanjavur          6
# Pudukkottai        5
# Erode              4
# Dharmapuri         4
# Thirupathur        4
# Ariyalur           4
# Tiruvarur          4
# Trichy             4
# Thanjavur          4
# Krishnagiri        4
# Salem              3
# Salem              3
# Dharmapuri         2
# Kallakurichi       2
# Theni              2
# coimbatore         2
# Tiruppur           2
# Cuddalore          2
# Viruthunagar       1
# Karur              1
# Tirupur            1
# Virudhunagar       1
# Nilgiris           1
# Tirunelveli        1
# Kanyakumari        1
# Ranipet            1
# Dindigul           1
# Villupuram         1
# Kallakurichi       1
# தென்காசி           1
# Pudukkotai         1
# Puthukkotai        1
# thanjavur          1
# Madurai            1
# Tenkasi            1
# Namakkal           1
# Perambalur         1
# Chennai            1
# Thothukudi         1
# Viruthachalam      1
# Tamil nadu         1
# PUDUKKOTTAI        1
# Name: count, dtype: int64
#
# ********** Area of Residence **********
# count                 201
# nunique                 2
# unique     [Urban, Rural]
# Name: Area of Residence, dtype: object
# value_counts:
#  Area of Residence
# Urban    127
# Rural     74
# Name: count, dtype: int64
#
# ********** which type of Vehicle do you have? **********
# count                                            201
# nunique                                            4
# unique     [Petrol, Diesel, Electric batteries, CNG]
# Name: which type of Vehicle do you have?, dtype: object
# value_counts:
#  which type of Vehicle do you have?
# Petrol                167
# Electric batteries     21
# Diesel                 12
# CNG                     1
# Name: count, dtype: int64
#
# ********** Do you have an Electric Vehicle? **********
# count            201
# nunique            2
# unique     [No, Yes]
# Name: Do you have an Electric Vehicle?, dtype: object
# value_counts:
#  Do you have an Electric Vehicle?
# No     166
# Yes     35
# Name: count, dtype: int64

# %%
discrete_univariate_analysis(data.iloc[ : ,9:13])
# Out:
# ********** 1.1 Are electric vehicles better performing compared to fuel vehicles? **********
# count                                           201
# nunique                                           5
# unique     [fair, good, poor, very poor, very good]
# Name: 1.1 Are electric vehicles better performing compared to fuel vehicles?, dtype: object
# value_counts:
#  1.1 Are electric vehicles better performing compared to fuel vehicles?
# good         129
# fair          45
# very good     14
# poor          12
# very poor      1
# Name: count, dtype: int64
#
# ********** 1.2  Are electric vehicles easy to drive then fuel vehicles? **********
# count                                              201
# nunique                                              5
# unique     [neutral, very easy, very hard, easy, hard]
# Name: 1.2  Are electric vehicles easy to drive then fuel vehicles?, dtype: object
# value_counts:
#  1.2  Are electric vehicles easy to drive then fuel vehicles?
# easy         90
# neutral      88
# very easy    18
# hard          3
# very hard     2
# Name: count, dtype: int64
#
# ********** 1.3 What is your opinion about blasting(firing) issues of electric vehicles? **********
# count                                            201
# nunique                                            5
# unique     [Often, Always, Sometimes, Rarely, Never]
# Name: 1.3 What is your opinion about blasting(firing) issues of electric vehicles?, dtype: object
# value_counts:
#  1.3 What is your opinion about blasting(firing) issues of electric vehicles?
# Sometimes    94
# Rarely       76
# Often        17
# Never         9
# Always        5
# Name: count, dtype: int64
#
# ********** 1.4 Do you agree that the EV’s are best alternative vehicles to fuel vehicles for reducing the fuel cost? **********
# count                                                    201
# nunique                                                    5
# unique     [Disagree, Neutral, Strongly agree, Agree, str...
# Name: 1.4 Do you agree that the EV’s are best alternative vehicles to fuel vehicles for reducing the fuel cost?, dtype: object
# value_counts:
#  1.4 Do you agree that the EV’s are best alternative vehicles to fuel vehicles for reducing the fuel cost?
# Agree                108
# Neutral               51
# Strongly agree        27
# Disagree               9
# strongly disagree      6
# Name: count, dtype: int64

# %%
discrete_univariate_analysis(data.iloc[ : ,13:18])
# Out:
# ********** 2.1  How does the performance of electric vehicles compared to fuel vehicles in your view? **********
# count                                           201
# nunique                                           5
# unique     [Good, Poor, Fair, Very good, Very poor]
# Name: 2.1  How does the performance of electric vehicles compared to fuel vehicles in your view?, dtype: object
# value_counts:
#  2.1  How does the performance of electric vehicles compared to fuel vehicles in your view?
# Good         99
# Fair         71
# Very good    17
# Poor         13
# Very poor     1
# Name: count, dtype: int64
#
# ********** 2.2 Do you agree that the EV’s are noiseless and offer smoother acceleration and declaration, avoid of the vibration, gear shifting and sounds of the internal consumption engine? **********
# count                                                    201
# nunique                                                    5
# unique     [Disagree, Neither agree or disagree, Strongly...
# Name: 2.2 Do you agree that the EV’s are noiseless and offer smoother acceleration and declaration, avoid of the vibration, gear shifting and sounds of the internal consumption engine?, dtype: object
# value_counts:
#  2.2 Do you agree that the EV’s are noiseless and offer smoother acceleration and declaration, avoid of the vibration, gear shifting and sounds of the internal consumption engine?
# Agree                        103
# Strongly agree                54
# Neither agree or disagree     29
# Disagree                       8
# Strongly disagree              7
# Name: count, dtype: int64
#
# ********** 2.3  How would you rate the driving experience of EV’s compared to traditional fuel vehicles? **********
# count                                              201
# nunique                                              5
# unique     [Similar, Very poor, Poor, Good, Very good]
# Name: 2.3  How would you rate the driving experience of EV’s compared to traditional fuel vehicles?, dtype: object
# value_counts:
#  2.3  How would you rate the driving experience of EV’s compared to traditional fuel vehicles?
# Good         100
# Similar       64
# Very good     18
# Poor          17
# Very poor      2
# Name: count, dtype: int64
#
# ********** 2.4  Are you satisfied with the overall cost of owning and maintaining EV’s compared to a fuel vehicles? **********
# count                                                    201
# nunique                                                    5
# unique     [Neither satisfied or dissatisfied, Dissatisfi...
# Name: 2.4  Are you satisfied with the overall cost of owning and maintaining EV’s compared to a fuel vehicles?, dtype: object
# value_counts:
#  2.4  Are you satisfied with the overall cost of owning and maintaining EV’s compared to a fuel vehicles?
# Satisfied                            106
# Neither satisfied or dissatisfied     66
# Very satisfied                        14
# Dissatisfied                          13
# Very dissatisfied                      2
# Name: count, dtype: int64
#
# ********** 2.5 Will electric vehicles refill the place of traditional fuel vehicles? **********
# count                                                    201
# nunique                                                    5
# unique     [Neutral, Definitely never refill, Never refil...
# Name: 2.5 Will electric vehicles refill the place of traditional fuel vehicles?, dtype: object
# value_counts:
#  2.5 Will electric vehicles refill the place of traditional fuel vehicles?
# Refill                     84
# Neutral                    51
# Definitely refill          34
# Never refill               23
# Definitely never refill     9
# Name: count, dtype: int64

# %%
discrete_univariate_analysis(data.iloc[ : ,18:22])
# Out:
# ********** 3.1 Is the charging type is better to fuel type in your site? **********
# count                                                 201
# nunique                                                 5
# unique     [Acceptable, Very poor, Poor, Good, Very good]
# Name: 3.1 Is the charging type is better to fuel type in your site?, dtype: object
# value_counts:
#  3.1 Is the charging type is better to fuel type in your site?
# Good          80
# Acceptable    71
# Poor          21
# Very good     19
# Very poor     10
# Name: count, dtype: int64
#
# ********** 3.2  What is your opinion on the availability and accessibility of charging stations for electric vehicles? **********
# count                                             201
# nunique                                             5
# unique     [Enough, Good, Poor, Very poor, Very good]
# Name: 3.2  What is your opinion on the availability and accessibility of charging stations for electric vehicles?, dtype: object
# value_counts:
#  3.2  What is your opinion on the availability and accessibility of charging stations for electric vehicles?
# Poor         71
# Very poor    43
# Good         43
# Enough       32
# Very good    12
# Name: count, dtype: int64
#
# ********** 3.3  Are the enough charging points in your area? **********
# count                                             201
# nunique                                             5
# unique     [Some one, Somewhat, Enough, Nothing, Lot]
# Name: 3.3  Are the enough charging points in your area?, dtype: object
# value_counts:
#  3.3  Are the enough charging points in your area?
# Nothing     83
# Some one    59
# Somewhat    31
# Enough      21
# Lot          7
# Name: count, dtype: int64
#
# ********** 3.4  What is your opinion on home charging? **********
# count                                                201
# nunique                                                5
# unique     [Good, Bad, Really bad, Neutral, Really good]
# Name: 3.4  What is your opinion on home charging?, dtype: object
# value_counts:
#  3.4  What is your opinion on home charging?
# Good           99
# Neutral        49
# Really good    27
# Bad            19
# Really bad      7
# Name: count, dtype: int64

# %%
discrete_univariate_analysis(data.iloc[ : ,22:27])
# Out:
# ********** 4.1  How do you precieve the initial cost of EV’s compared to traditional vehicles? **********
# count                                                    201
# nunique                                                    5
# unique     [Expensive, Very cheap, both are same, Cheap, ...
# Name: 4.1  How do you precieve the initial cost of EV’s compared to traditional vehicles?, dtype: object
# value_counts:
#  4.1  How do you precieve the initial cost of EV’s compared to traditional vehicles?
# both are same     76
# Cheap             56
# Expensive         45
# Very cheap        13
# very expensive    11
# Name: count, dtype: int64
#
# ********** 4.2 How much cheaper is electricity generally than petrol or diesel per mile? **********
# count                                                    201
# nunique                                                    5
# unique     [Expensive, Both are same, Cheap, Very cheap, ...
# Name: 4.2 How much cheaper is electricity generally than petrol or diesel per mile?, dtype: object
# value_counts:
#  4.2 How much cheaper is electricity generally than petrol or diesel per mile?
# Cheap             99
# Both are same     66
# Very cheap        21
# Expensive         12
# Very expensive     3
# Name: count, dtype: int64
#
# ********** 4.3  How is the maintenance cost of EV’s compared to fuel vehicles? **********
# count                                                    201
# nunique                                                    5
# unique     [Both are same, Expensive, Cheap, Very cheap, ...
# Name: 4.3  How is the maintenance cost of EV’s compared to fuel vehicles?, dtype: object
# value_counts:
#  4.3  How is the maintenance cost of EV’s compared to fuel vehicles?
# Both are same     98
# Cheap             60
# Expensive         27
# Very cheap        10
# very expensive     6
# Name: count, dtype: int64
#
# ********** 4.4  What is your opinion on cost of buying spare parts of electric vehicles in Tamil Nadu? **********
# count                                                    201
# nunique                                                    5
# unique     [similar to others, High, Low, Very high, Very...
# Name: 4.4  What is your opinion on cost of buying spare parts of electric vehicles in Tamil Nadu?, dtype: object
# value_counts:
#  4.4  What is your opinion on cost of buying spare parts of electric vehicles in Tamil Nadu?
# similar to others    94
# Low                  43
# High                 42
# Very high            15
# Very low              7
# Name: count, dtype: int64
#
# ********** 4.5   How is the resale value of an EV's compared to a traditional fuel vehicles? **********
# count                                            201
# nunique                                            5
# unique     [High, Low, Very low, Neutral, Very high]
# Name: 4.5   How is the resale value of an EV's compared to a traditional fuel vehicles?, dtype: object
# value_counts:
#  4.5   How is the resale value of an EV's compared to a traditional fuel vehicles?
# Neutral      66
# Very low     58
# Low          46
# High         22
# Very high     9
# Name: count, dtype: int64

# %%
discrete_univariate_analysis(data.iloc[ : ,27:32])
# Out:
# ********** 5.1  How familiar are you with EV’s and their features? **********
# count                                                    201
# nunique                                                    5
# unique     [familiar, Very unfamiliar, Somewhat familiar,...
# Name: 5.1  How familiar are you with EV’s and their features?, dtype: object
# value_counts:
#  5.1  How familiar are you with EV’s and their features?
# familiar             92
# Somewhat familiar    57
# Unfamiliiar          25
# Very familiar        22
# Very unfamiliar       5
# Name: count, dtype: int64
#
# ********** 5.2  Are you attracted to EV’s because of the technological advancement? **********
# count                                                    201
# nunique                                                    5
# unique     [Attracted, Highly not attracted, Not attracte...
# Name: 5.2  Are you attracted to EV’s because of the technological advancement?, dtype: object
# value_counts:
#  5.2  Are you attracted to EV’s because of the technological advancement?
# Attracted               97
# Somewhat attracted      62
# Highly attracted        21
# Not attracted           16
# Highly not attracted     5
# Name: count, dtype: int64
#
# ********** 5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles? **********
# count                                                    201
# nunique                                                    5
# unique     [Very satisfied, moderately satisfied, Slightl...
# Name: 5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles?, dtype: object
# value_counts:
#  5.3   Are you satisfied with the range of EV’s comparing to traditional fuel vehicles?
# moderately satisfied    88
# Very satisfied          70
# Slightly satisfied      23
# Extremely satisfied     13
# Not at all satisfied     7
# Name: count, dtype: int64
#
# ********** 5.4  If you were to buy a vehicle, would you consider EV’s? **********
# count                                                    201
# nunique                                                    5
# unique     [Somewhat considered, Not considered, Consider...
# Name: 5.4  If you were to buy a vehicle, would you consider EV’s?, dtype: object
# value_counts:
#  5.4  If you were to buy a vehicle, would you consider EV’s?
# Somewhat considered      105
# Considered                63
# Not considered            15
# Highly considered         15
# Highly not considered      3
# Name: count, dtype: int64
#
# ********** 5.5 What do you think of the government encouraging e-vehicle sales? **********
# count                                         201
# nunique                                         5
# unique     [Good, Average, Fair, Excellent, Poor]
# Name: 5.5 What do you think of the government encouraging e-vehicle sales?, dtype: object
# value_counts:
#  5.5 What do you think of the government encouraging e-vehicle sales?
# Average      60
# Poor         54
# Good         50
# Excellent    24
# Fair         13
# Name: count, dtype: int64

# %%
discrete_univariate_analysis(data.iloc[ : ,32:36])
# Out:
# ********** 6.1  Are electric vehicles polluting like other traditional fuel vehicles? **********
# count                                                    201
# nunique                                                    5
# unique     [Similar to others, Highly polluting, Not poll...
# Name: 6.1  Are electric vehicles polluting like other traditional fuel vehicles?, dtype: object
# value_counts:
#  6.1  Are electric vehicles polluting like other traditional fuel vehicles?
# Highly not polluting    76
# Not polluting           66
# Similar to others       45
# slightly polluting       9
# Highly polluting         5
# Name: count, dtype: int64
#
# ********** 6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment? **********
# count                                                    201
# nunique                                                    5
# unique     [Neutral, Useless, Usefull, Very usefull, Very...
# Name: 6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment?, dtype: object
# value_counts:
#  6.2  What is your opinion about that the absents of tailpipe emissions from EV’s contributes to better air quality, reducing pollutants that can have adverse effects on human health and the environment?
# Usefull         76
# Very usefull    66
# Neutral         46
# Useless          8
# Very useless     5
# Name: count, dtype: int64
#
# ********** 6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces? **********
# count                                                    201
# nunique                                                    5
# unique     [Reduce, Didn't reduce, Definitely reduce, Sim...
# Name: 6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces?, dtype: object
# value_counts:
#  6.3  Because electric vehicles are soundless than traditional vehicles, do they reduce noise pollution especially in public spaces?
# Definitely reduce           87
# Reduce                      69
# Similar to others           35
# Didn't reduce                7
# Definitely didn't reduce     3
# Name: count, dtype: int64
#
# ********** 6.4  Are the applications of EV’s support to eco- friendly transportation? **********
# count                                                    201
# nunique                                                    5
# unique     [neutral, support, definitely support, never s...
# Name: 6.4  Are the applications of EV’s support to eco- friendly transportation?, dtype: object
# value_counts:
#  6.4  Are the applications of EV’s support to eco- friendly transportation?
# definitely support          78
# support                     65
# neutral                     50
# never support                7
# definitely never support     1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(data['Gender'], kde=False, bins=5)
plt.xlabel('Gender')
plt.ylabel('Ferquency')
plt.title('Histogram using seaborn')
plt.show()

# %%
sns.countplot(data['Age'])
plt.xlabel('Frequency')
plt.ylabel('Age')
plt.title('Countlot using seaborn')
plt.show()

# %%
sns.histplot(data['Employment Status'], kde=False, bins=5)
plt.xlabel('Employment status')
plt.ylabel('Frequency')
plt.title('histplot using seaborn')

plt.show()

# %%
edu_q=data['Education Qualification '].value_counts()
plt.figure(figsize=(6,4))
plt.pie(edu_q, labels=edu_q.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Pie chart of Educational qualification')
plt.show()

# %%
sns.barplot(data['Area of Residence'])
plt.xlabel('Frequency')
plt.ylabel('Are')
plt.title('Barplot using seaborn')
plt.show()

# %%
type_of_vehicles=data.iloc[ : ,7:8].value_counts()
plt.pie(type_of_vehicles, labels=type_of_vehicles.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Pie chart for types of vehicles')
plt.show()

# %%
sns.countplot(data['Do you have an Electric Vehicle?'])
plt.xlabel('Frequency')
plt.ylabel('Options')
plt.title('Countplot using seaborn')
plt.show()
