# %%
import pandas as pd

# %%
df=pd.read_csv('d:/pg project responses/analyze using python/cust_res.csv')
df
# Out:
#      Unnamed: 0             Name  Gender      Age Employment Status  \
# 0             0  Anish Glorisha   Female  18 - 27           Student
# 1             1             Hari    Male  18 - 27           Student
# 2             2  CHINNAPPANDI J     Male  18 - 27           Student
# 3             3    P. Manikandan    Male  18 - 27           Student
# 4             4        Divyasri   Female  18 - 27           Student
# ..          ...              ...     ...      ...               ...
# 196         196      Karuppaiya     Male  28 - 43          Employed
# 197         197           Vishal    Male  18 - 27          Employed
# 198         198          Nivedha  Female  18 - 27          Employed
# 199         199          Xavier     Male  18 - 27          Employed
# 200         200   S.Gangaiarasan    Male  44 - 59          Employed
#
#     Education Qualification       District Area of Residence  \
# 0              Post Graduate   Coimbatore              Urban
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Gender', 'Age', 'Employment Status',
#        'Education Qualification ', 'District', 'Area of Residence',
#        'type of vehicle', 'EV', '1.1 current awareness',
#        '1.2 current awareness', '1.3 current awareness',
#        '1.4 current awareness', '2.1 user satisfaction',
#        '2.2 user satisfaction', '2.3 user satisfaction',
#        '2.4 user satisfaction', '2.5 user satisfaction',
#        '3.1 charging facilities', '3.2 charging facilities',
#        '3.3 charging facilities', '3.4 charging facilities',
#        '4.1 cost consideration', '4.2 cost consideration',
#        '4.3 cost consideration', '4.4 cost consideration',
#        '4.5 cost consideration', '5.1 consumer preference',
#        '5.2 consumer preference', '5.3 consumer preference',
#        '5.4 consumer preference', '5.5 consumer preference',
#        '6.1 evm consideration', '6.2 evm consideration',
#        '6.3 evm consideration', '6.4 evm consideration'],
# ...

# %%
temp=df.groupby('Employment Status')['1.1 current awareness'].value_counts()
temp.sort_index()
pd.DataFrame('temp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4704\759714972.py in ?()
#       1 temp=df.groupby('Employment Status')['1.1 current awareness'].value_counts()
#       2 temp.sort_index()
# ----> 3 pd.DataFrame('temp')
#
# c:\Users\ANAND\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
